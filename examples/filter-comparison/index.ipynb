# %% [markdown]
# ---
# title: "Digital Twins"
# author: Grant and company
# date: last-modified
# engine: julia
# julia:
#     exeflags: ["--project=."]
# toc: true
# toc-depth: 4
# toc-expand: 2
# toc-title: Outline
# toc-location: left
# format:
#     html:
#         linkcolor: black
#         theme: cosmo
#         lightbox: true
#         crossrefs-hover: true
#         include-in-header: mathjax.html
#         code-overflow: wrap
# ---
#
# # Digital twins in Julia

# %%
Base.active_project()
# Out:
# "/home/gbruer/a/r/JutulJUDIFilter.jl/examples/filter-comparison/Project.toml"

# %% [markdown]
# ## Get things installed

# %%
include("src/install.jl")
include("src/generate_ground_truth.jl")
include("src/plotting_plumes.jl")
include("src/generate_initial_ensemble.jl")
include("src/run_estimator.jl")

# %% [markdown]
# ## Set params

# %%
params = include("params/tutorial-params.jl")
filestem = "tutorial"
# Out:
# "tutorial"

# %% [markdown]
# ## Run ground-truth

# %%
params_gt = params.ground_truth
filestem = "tutorial-ground-truth"

params_file = datadir("ground_truth", "params", "$filestem.jld2")
wsave(params_file; params=params_gt)

params_file = datadir("ground_truth", "params", "$filestem-human.yaml")
YAML.write_file(params_file, to_dict(params_gt, YAMLStyle))

println(YAML.write(to_dict(params_gt, YAMLStyle)))
# Out:
# version: "v0.2"
# transition:
#   mesh:
#     n: (100, 1, 100)
#     d: (40, 100.0, 20)
#     origin: (0.0, 0.0, 0.0)
#   nt: 25
#   system:
#     viscosity_CO2: 0.0001
#     viscosity_H2O: 0.001
#     density_CO2: 501.9
#     density_H2O: 1053.0
#     reference_pressure: 1.5e7
#     compressibility_CO2: 8.0e-9
#     compressibility_H2O: 3.6563071e-10
#     extra_kwargs: NamedTuple()
#   dt: 73.0485
#   nbatches: 1
#   kv_over_kh: 0.36
#   sat0_radius_cells: 4
#   sat0_range: (0.2, 0.8)
#   fluid1:
#     name: "H₂O"
#     viscosity: 0.001
#     density: 1053.0
#     compressibility: 3.6563071e-10
#   fluid2:
#     name: "CO₂"
#     viscosity: 0.0001
#     density: 776.6
#     compressibility: 8.0e-9
#   g: 9.81
#   reference_pressure: 1.5e7
#   porosity:
#     name: field
#     suboptions:
#       value: 0.25
#   permeability:
#     name: field
#     suboptions:
#       file: "compass_small/perm_poro.jld2"
#       idx: ~
#       key: "K"
#       scale: 9.86923266716013e-16
#       resize: true
#   permeability_v_over_h: 0.36
#   temperature:
#     name: field
#     suboptions:
#       value: 303.15
#   rock_density:
#     name: field
#     suboptions:
#       value: 30.0
#   rock_heat_capacity:
#     name: field
#     suboptions:
#       value: 900.0
#   rock_thermal_conductivity:
#     name: field
#     suboptions:
#       value: 3
#   fluid_thermal_conductivity:
#     name: field
#     suboptions:
#       value: 0.6
#   component_heat_capacity:
#     name: field
#     suboptions:
#       value: 4184.0
#   injection:
#     active: true
#     trajectory: ([1875.0, 50.0, 1775.0], [1875.0, 50.0, 1812.5])
#     simple_well: true
#     name: Injector
#   production:
#     active: false
#     trajectory: ([2875.0, 50.0, 1693.75], [2875.0, 50.0, 1731.25])
#     simple_well: true
#     name: Producer
#   time: (TimeDependentOptions(5.0, 1, (WellRateOptions("injector", :Injector, 501.9, 0.8),)), TimeDependentOptions(475.0, 1, ()))
# observation:
#   observers: (Pair{Float64, Any}(3.1556952e7, SeismicCO2ObserverOptions(SeismicObserverOptions((type = :squared_slowness, field = FieldOptions(:field, FieldFileOptions("compass_small/BGCompass_tti_625m.jld2", nothing, "m", 1.0e-6, true))), FieldOptions(:field, FieldFileOptions("compass_small/BGCompass_tti_625m.jld2", nothing, "rho", 1000.0, true)), MeshOptions((100, 100), (40, 20), (0.0, 0.0, 0.0)), :born_shot_rtm_depth_noise, BackgroundBlurOptions(10.0), BackgroundBlurOptions(10.0), 80, 1800.0, 4.0, 0.024, SourceReceiverGeometryOptions(4, 50, :surface), 1, 8.0, 0xb874e67219a0aba4), RockPhysicsModelOptions(501.9, 1053.0, 3.66e10, 2.735e9, 1.25e8, FieldOptions(:field, FieldConstantOptions(0.25))))), Pair{Float64, Any}(6.3113904e7, SeismicCO2ObserverOptions(SeismicObserverOptions((type = :squared_slowness, field = FieldOptions(:field, FieldFileOptions("compass_small/BGCompass_tti_625m.jld2", nothing, "m", 1.0e-6, true))), FieldOptions(:field, FieldFileOptions("compass_small/BGCompass_tti_625m.jld2", nothing, "rho", 1000.0, true)), MeshOptions((100, 100), (40, 20), (0.0, 0.0, 0.0)), :born_shot_rtm_depth_noise, BackgroundBlurOptions(10.0), BackgroundBlurOptions(10.0), 80, 1800.0, 4.0, 0.024, SourceReceiverGeometryOptions(4, 50, :surface), 1, 8.0, 0xb874e67219a0aba4), RockPhysicsModelOptions(501.9, 1053.0, 3.66e10, 2.735e9, 1.25e8, FieldOptions(:field, FieldConstantOptions(0.25))))), Pair{Float64, Any}(9.4670856e7, SeismicCO2ObserverOptions(SeismicObserverOptions((type = :squared_slowness, field = FieldOptions(:field, FieldFileOptions("compass_small/BGCompass_tti_625m.jld2", nothing, "m", 1.0e-6, true))), FieldOptions(:field, FieldFileOptions("compass_small/BGCompass_tti_625m.jld2", nothing, "rho", 1000.0, true)), MeshOptions((100, 100), (40, 20), (0.0, 0.0, 0.0)), :born_shot_rtm_depth_noise, BackgroundBlurOptions(10.0), BackgroundBlurOptions(10.0), 80, 1800.0, 4.0, 0.024, SourceReceiverGeometryOptions(4, 50, :surface), 1, 8.0, 0xb874e67219a0aba4), RockPhysicsModelOptions(501.9, 1053.0, 3.66e10, 2.735e9, 1.25e8, FieldOptions(:field, FieldConstantOptions(0.25))))), Pair{Float64, Any}(1.26227808e8, SeismicCO2ObserverOptions(SeismicObserverOptions((type = :squared_slowness, field = FieldOptions(:field, FieldFileOptions("compass_small/BGCompass_tti_625m.jld2", nothing, "m", 1.0e-6, true))), FieldOptions(:field, FieldFileOptions("compass_small/BGCompass_tti_625m.jld2", nothing, "rho", 1000.0, true)), MeshOptions((100, 100), (40, 20), (0.0, 0.0, 0.0)), :born_shot_rtm_depth_noise, BackgroundBlurOptions(10.0), BackgroundBlurOptions(10.0), 80, 1800.0, 4.0, 0.024, SourceReceiverGeometryOptions(4, 50, :surface), 1, 8.0, 0xb874e67219a0aba4), RockPhysicsModelOptions(501.9, 1053.0, 3.66e10, 2.735e9, 1.25e8, FieldOptions(:field, FieldConstantOptions(0.25))))), Pair{Float64, Any}(1.5778476e8, SeismicCO2ObserverOptions(SeismicObserverOptions((type = :squared_slowness, field = FieldOptions(:field, FieldFileOptions("compass_small/BGCompass_tti_625m.jld2", nothing, "m", 1.0e-6, true))), FieldOptions(:field, FieldFileOptions("compass_small/BGCompass_tti_625m.jld2", nothing, "rho", 1000.0, true)), MeshOptions((100, 100), (40, 20), (0.0, 0.0, 0.0)), :born_shot_rtm_depth_noise, BackgroundBlurOptions(10.0), BackgroundBlurOptions(10.0), 80, 1800.0, 4.0, 0.024, SourceReceiverGeometryOptions(4, 50, :surface), 1, 8.0, 0xb874e67219a0aba4), RockPhysicsModelOptions(501.9, 1053.0, 3.66e10, 2.735e9, 1.25e8, FieldOptions(:field, FieldConstantOptions(0.25))))))
# max_transition_step: ~

# %%
savedir = datadir("ground_truth", "data")
data_gt, filepath = produce_or_load(
    generate_ground_truth,
    params_gt,
    savedir;
    filename=filestem,
    verbose=false,
    force=true,
)
states = data_gt["states"]
observations = data_gt["observations"]
observations_clean = data_gt["observations_clean"]
state_times = data_gt["state_times"]
observation_times = data_gt["observation_times"];
# Out:
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │ 11 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     54.0 │      4.90909 │   54 (0) │
# │ Linearization  │     65.0 │      5.90909 │   65 (0) │
# │ Linear solver  │    140.0 │      12.7273 │  140 (0) │
# │ Precond apply  │    280.0 │      25.4545 │  280 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬──────────┬────────────┬────────╮
# │ Timing type   │     Each │   Relative │  Total │
# │               │       ms │ Percentage │      s │
# ├───────────────┼──────────┼────────────┼────────┤
# │ Properties    │   0.8227 │     0.59 % │ 0.0444 │
# │ Equations     │  31.4125 │    26.98 % │ 2.0418 │
# │ Assembly      │  13.0973 │    11.25 % │ 0.8513 │
# │ Linear solve  │   8.8625 │     6.32 % │ 0.4786 │
# │ Linear setup  │  28.8724 │    20.60 % │ 1.5591 │
# │ Precond apply │   1.3654 │     5.05 % │ 0.3823 │
# │ Update        │   4.4179 │     3.15 % │ 0.2386 │
# │ Convergence   │  11.7742 │    10.11 % │ 0.7653 │
# │ Input/Output  │   4.3126 │     0.63 % │ 0.0474 │
# │ Other         │  21.4456 │    15.30 % │ 1.1581 │
# ├───────────────┼──────────┼────────────┼────────┤
# │ Total         │ 140.1286 │   100.00 % │ 7.5669 │
# ╰───────────────┴──────────┴────────────┴────────╯
# Noise norm: 3.3969563e11
# SNR: 8.0
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │  7 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     32.0 │      4.57143 │   32 (0) │
# │ Linearization  │     39.0 │      5.57143 │   39 (0) │
# │ Linear solver  │     98.0 │         14.0 │   98 (0) │
# │ Precond apply  │    196.0 │         28.0 │  196 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.8406 │     4.51 % │  26.8983 │
# │ Equations     │  2.1772 │    14.23 % │  84.9106 │
# │ Assembly      │  0.8576 │     5.60 % │  33.4483 │
# │ Linear solve  │  1.5704 │     8.42 % │  50.2541 │
# │ Linear setup  │  6.1758 │    33.11 % │ 197.6251 │
# │ Precond apply │  0.9051 │    29.72 % │ 177.3921 │
# │ Update        │  0.3869 │     2.07 % │  12.3806 │
# │ Convergence   │  0.1920 │     1.25 % │   7.4871 │
# │ Input/Output  │  0.0298 │     0.03 % │   0.2084 │
# │ Other         │  0.1968 │     1.06 % │   6.2977 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 18.6532 │   100.00 % │ 596.9022 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# Noise norm: 3.397297e11
# SNR: 8.0
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │  6 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     21.0 │          3.5 │   21 (0) │
# │ Linearization  │     27.0 │          4.5 │   27 (0) │
# │ Linear solver  │     64.0 │      10.6667 │   64 (0) │
# │ Precond apply  │    128.0 │      21.3333 │  128 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.8150 │     4.47 % │  17.1155 │
# │ Equations     │  2.1299 │    15.00 % │  57.5072 │
# │ Assembly      │  0.8338 │     5.87 % │  22.5134 │
# │ Linear solve  │  1.5637 │     8.57 % │  32.8373 │
# │ Linear setup  │  5.7333 │    31.41 % │ 120.3991 │
# │ Precond apply │  0.8963 │    29.93 % │ 114.7323 │
# │ Update        │  0.3757 │     2.06 % │   7.8907 │
# │ Convergence   │  0.1855 │     1.31 % │   5.0083 │
# │ Input/Output  │  0.0389 │     0.06 % │   0.2334 │
# │ Other         │  0.2402 │     1.32 % │   5.0448 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 18.2515 │   100.00 % │ 383.2820 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# Noise norm: 3.3922862e11
# SNR: 8.0
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │  6 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     21.0 │          3.5 │   21 (0) │
# │ Linearization  │     27.0 │          4.5 │   27 (0) │
# │ Linear solver  │     67.0 │      11.1667 │   67 (0) │
# │ Precond apply  │    134.0 │      22.3333 │  134 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.8024 │     4.40 % │  16.8499 │
# │ Equations     │  2.1144 │    14.89 % │  57.0898 │
# │ Assembly      │  0.8305 │     5.85 % │  22.4227 │
# │ Linear solve  │  1.5861 │     8.69 % │  33.3074 │
# │ Linear setup  │  5.5565 │    30.44 % │ 116.6863 │
# │ Precond apply │  0.8902 │    31.12 % │ 119.2822 │
# │ Update        │  0.3691 │     2.02 % │   7.7518 │
# │ Convergence   │  0.1790 │     1.26 % │   4.8343 │
# │ Input/Output  │  0.0243 │     0.04 % │   0.1458 │
# │ Other         │  0.2372 │     1.30 % │   4.9819 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 18.2549 │   100.00 % │ 383.3521 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# Noise norm: 3.3804124e11
# SNR: 8.0
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │  5 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     23.0 │          4.6 │   23 (0) │
# │ Linearization  │     28.0 │          5.6 │   28 (0) │
# │ Linear solver  │     72.0 │         14.4 │   72 (0) │
# │ Precond apply  │    144.0 │         28.8 │  144 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.8030 │     2.07 % │  18.4700 │
# │ Equations     │  2.1480 │     6.75 % │  60.1450 │
# │ Assembly      │  0.9396 │     2.95 % │  26.3079 │
# │ Linear solve  │  1.6001 │     4.13 % │  36.8022 │
# │ Linear setup  │  5.6447 │    14.56 % │ 129.8271 │
# │ Precond apply │  0.9074 │    14.66 % │ 130.6585 │
# │ Update        │  0.3767 │     0.97 % │   8.6640 │
# │ Convergence   │ 17.0003 │    53.40 % │ 476.0095 │
# │ Input/Output  │  0.0339 │     0.02 % │   0.1695 │
# │ Other         │  0.1920 │     0.50 % │   4.4150 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 38.7595 │   100.00 % │ 891.4688 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# Noise norm: 3.360016e11
# SNR: 8.0
# 142.646094 seconds (88.70 M allocations: 7.416 GiB, 32.97% gc time, 31.30% compilation time: 7% of which was recompilation)
#   ^ timing for making ground truth data

# %%
@show length(states)
@show length(state_times)
@show keys(states[1])
@show keys(observations[1])
@show length(observations)
@show length(observation_times);
# Out:
# length(states) = 6
# length(state_times) = 6
# keys(states[1]) = [:Permeability, :Injector_Pressure, :Saturation, :Pressure, :Facility_TotalSurfaceMassRate, :Injector_Saturations]
# keys(observations[1]) = [:dshot, :rtm]
# length(observations) = 5
# length(observation_times) = 5

# %%
CairoMakie.activate!()
grid_2d = get_2d_plotting_mesh(params_gt.transition.mesh)
# Out:
# MeshOptions((100, 100), (0.04, 0.02), (0.0, 0.0))

# %%
fig = Figure()
data = states[1][:Permeability]
@show size(data)
content_layout = GridLayout(fig[1,1])
plot_scalar_field(content_layout, Observable(data[1, :]); grid_2d, heatmap_kwargs=(; colormap=Reverse(:Purples)))
fig
# Out:
# size(data) = (3, 10000)

# %%
fig = Figure()
t_idx = Observable(1)
data = @lift(states[$t_idx][:Saturation])
content_layout = GridLayout(fig[1,1])
plot_scalar_field(content_layout, data; grid_2d, heatmap_kwargs=(; colorrange=(0,1), colormap=parula))
for i = 1:length(states)
    t_idx[] = i
    display(fig)
end

# %%
fig = Figure()
t_idx = Observable(1)
data = @lift(states[$t_idx][:Pressure] .- states[1][:Pressure])
content_layout = GridLayout(fig[1,1])
plot_scalar_field(content_layout, data; grid_2d, heatmap_kwargs=(; make_divergent=true, colormap=Reverse(:RdBu)))
for i = 1:length(states)
    t_idx[] = i
    display(fig)
end

# %%
fig = Figure()
t_idx = Observable(1)
data = @lift(observations[$t_idx][:rtm] .- observations[1][:rtm])
content_layout = GridLayout(fig[1,1])
plot_scalar_field(content_layout, data; grid_2d, heatmap_kwargs=(; make_divergent=true, colormap=Reverse(:RdBu)))
for i = 1:length(observations)
    t_idx[] = i
    display(fig)
end

# %%
fig = Figure()
t_idx = Observable(1)
function dshot_diff(state)
    return [d .- d0 for (d0, d) in zip(observations[1][:dshot], state[:dshot])]
end
data = @lift(dshot_diff(observations[$t_idx]))
content_layout = GridLayout(fig[1,1])
timeR = @lift(params_gt.observation.observers[$t_idx].second.seismic.timeR)
dtR = @lift(params_gt.observation.observers[$t_idx].second.seismic.dtR)
nsrc = params_gt.observation.observers[1].second.seismic.source_receiver_geometry.nsrc
plot_data(content_layout, data, nothing, :dshot; heatmap_kwargs=(; make_divergent=true, colormap=Reverse(:RdBu)), nsrc, timeR, dtR)
for i = 1:length(observations)
    t_idx[] = i
    display(fig)
end
# Out:
# src_range = 1:1:4
# Plotting source 1 at CartesianIndex(1, 1)
# Plotting source 2 at CartesianIndex(2, 1)
# Plotting source 3 at CartesianIndex(3, 1)
# Plotting source 4 at CartesianIndex(4, 1)

# %% [markdown]
# ## Create initial ensemble.

# %%
filestem = "tutorial-initial-ensemble"

params_file = datadir("initial_ensemble", "params", "$filestem.jld2")
wsave(params_file; params=params.ensemble)

params_file = datadir("initial_ensemble", "params", "$filestem-human.yaml")
YAML.write_file(params_file, to_dict(params.ensemble, YAMLStyle))

println(YAML.write(to_dict(params.ensemble, YAMLStyle)))
# Out:
# version: "v0.1"
# size: 2
# seed: 9347215
# mesh:
#   n: (100, 1, 100)
#   d: (40, 100.0, 20)
#   origin: (0.0, 0.0, 0.0)
# permeability_v_over_h: 0.36
# prior: (Saturation = GaussianPriorOptions(0, 0), Permeability = FieldOptions(:field, FieldFileOptions("compass_small/perm_poro.jld2", nothing, "Ks", 9.86923266716013e-16, true)))

# %%
savedir = datadir("initial_ensemble", "data")
data_initial, filepath = produce_or_load(
    generate_initial_ensemble,
    params.ensemble,
    savedir;
    filename=filestem,
    verbose=false,
    loadfile=true,
)
ensemble = data_initial["ensemble"];

# %%
fig = Figure()
e_idx = Observable(1)
data = @lift(ensemble.members[$e_idx][:Permeability][1, :])
content_layout = GridLayout(fig[1,1])
plot_scalar_field(content_layout, data; grid_2d, heatmap_kwargs=(; colormap=Reverse(:Purples)))
for i = 1:min(length(ensemble.members), 3)
    e_idx[] = i
    display(fig)
end

# %% [markdown]
# ## Run estimator

# %%
filestem = "tutorial-estimator"

params_file = datadir("estimator", "params", "$filestem.jld2")
wsave(params_file; params=params.estimator)

params_file = datadir("estimator", "params", "$filestem-human.yaml")
YAML.write_file(params_file, to_dict(params.ensemble, YAMLStyle))

println(YAML.write(to_dict(params.ensemble, YAMLStyle)))
# Out:
# version: "v0.1"
# size: 2
# seed: 9347215
# mesh:
#   n: (100, 1, 100)
#   d: (40, 100.0, 20)
#   origin: (0.0, 0.0, 0.0)
# permeability_v_over_h: 0.36
# prior: (Saturation = GaussianPriorOptions(0, 0), Permeability = FieldOptions(:field, FieldFileOptions("compass_small/perm_poro.jld2", nothing, "Ks", 9.86923266716013e-16, true)))

# %%
savedir = datadir("estimator", "data")

states_gt = data_gt["states"]
observations_gt = data_gt["observations"]

ensemble = data_initial["ensemble"]

K = (Val(:Saturation), Val(:Pressure), Val(:Permeability))
JMT = JutulModelTranslator(K)

M = JutulModel(; translator=JMT, options=params.estimator.transition)
observers = get_multi_time_observer(params.estimator.observation)

# Initialize member for all primary variables in simulation.
@progress "Initialize ensemble states" for member in get_ensemble_members(ensemble)
    initialize_member!(M, member)
end

estimator = get_estimator(params.estimator.algorithm)

empty!(ensemble.state_keys)
append!(ensemble.state_keys, params.estimator.assimilation_keys)

t0 = 0.0
data = filter_loop(
    ensemble,
    t0,
    estimator,
    M,
    observers,
    observations_gt;
    name=get_short_name(params.estimator.algorithm),
    max_transition_step = params.estimator.max_transition_step,
)
# Out:
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │ 11 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     54.0 │      4.90909 │   54 (0) │
# │ Linearization  │     65.0 │      5.90909 │   65 (0) │
# │ Linear solver  │    147.0 │      13.3636 │  147 (0) │
# │ Precond apply  │    294.0 │      26.7273 │  294 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.8286 │     4.53 % │  44.7460 │
# │ Equations     │  2.2096 │    14.54 % │ 143.6263 │
# │ Assembly      │  0.8429 │     5.55 % │  54.7898 │
# │ Linear solve  │  1.4648 │     8.01 % │  79.0983 │
# │ Linear setup  │  6.5909 │    36.02 % │ 355.9083 │
# │ Precond apply │  0.9044 │    26.91 % │ 265.9069 │
# │ Update        │  0.3854 │     2.11 % │  20.8092 │
# │ Convergence   │  0.1958 │     1.29 % │  12.7286 │
# │ Input/Output  │  0.0320 │     0.04 % │   0.3522 │
# │ Other         │  0.1869 │     1.02 % │  10.0906 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 18.2973 │   100.00 % │ 988.0562 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │ 11 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     54.0 │      4.90909 │   54 (0) │
# │ Linearization  │     65.0 │      5.90909 │   65 (0) │
# │ Linear solver  │    148.0 │      13.4545 │  148 (0) │
# │ Precond apply  │    296.0 │      26.9091 │  296 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.8322 │     4.72 % │  44.9397 │
# │ Equations     │  2.2069 │    15.08 % │ 143.4462 │
# │ Assembly      │  0.8461 │     5.78 % │  54.9984 │
# │ Linear solve  │  1.4773 │     8.39 % │  79.7745 │
# │ Linear setup  │  5.8422 │    33.17 % │ 315.4793 │
# │ Precond apply │  0.9080 │    28.26 % │ 268.7821 │
# │ Update        │  0.3871 │     2.20 % │  20.9057 │
# │ Convergence   │  0.1955 │     1.34 % │  12.7105 │
# │ Input/Output  │  0.0232 │     0.03 % │   0.2555 │
# │ Other         │  0.1841 │     1.05 % │   9.9413 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 17.6154 │   100.00 % │ 951.2332 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │ 11 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     55.0 │          5.0 │   55 (0) │
# │ Linearization  │     66.0 │          6.0 │   66 (0) │
# │ Linear solver  │    139.0 │      12.6364 │  139 (0) │
# │ Precond apply  │    278.0 │      25.2727 │  278 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.8262 │     4.79 % │  45.4388 │
# │ Equations     │  2.1996 │    15.30 % │ 145.1715 │
# │ Assembly      │  0.8508 │     5.92 % │  56.1530 │
# │ Linear solve  │  1.3850 │     8.03 % │  76.1752 │
# │ Linear setup  │  5.9891 │    34.71 % │ 329.4005 │
# │ Precond apply │  0.9087 │    26.62 % │ 252.6164 │
# │ Update        │  0.3905 │     2.26 % │  21.4799 │
# │ Convergence   │  0.1900 │     1.32 % │  12.5384 │
# │ Input/Output  │  0.0241 │     0.03 % │   0.2651 │
# │ Other         │  0.1800 │     1.04 % │   9.9013 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 17.2571 │   100.00 % │ 949.1402 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │ 11 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     55.0 │          5.0 │   55 (0) │
# │ Linearization  │     66.0 │          6.0 │   66 (0) │
# │ Linear solver  │    144.0 │      13.0909 │  144 (0) │
# │ Precond apply  │    288.0 │      26.1818 │  288 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.7709 │     4.63 % │  42.3997 │
# │ Equations     │  2.1326 │    15.38 % │ 140.7518 │
# │ Assembly      │  0.8331 │     6.01 % │  54.9828 │
# │ Linear solve  │  1.3753 │     8.26 % │  75.6400 │
# │ Linear setup  │  5.4976 │    33.03 % │ 302.3690 │
# │ Precond apply │  0.8950 │    28.16 % │ 257.7695 │
# │ Update        │  0.3631 │     2.18 % │  19.9703 │
# │ Convergence   │  0.1774 │     1.28 % │  11.7098 │
# │ Input/Output  │  0.0193 │     0.02 % │   0.2123 │
# │ Other         │  0.1732 │     1.04 % │   9.5279 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 16.6424 │   100.00 % │ 915.3332 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │ 11 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     58.0 │      5.27273 │   58 (0) │
# │ Linearization  │     69.0 │      6.27273 │   69 (0) │
# │ Linear solver  │    144.0 │      13.0909 │  144 (0) │
# │ Precond apply  │    288.0 │      26.1818 │  288 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.8203 │     4.87 % │  47.5795 │
# │ Equations     │  2.1913 │    15.46 % │ 151.1976 │
# │ Assembly      │  0.8436 │     5.95 % │  58.2086 │
# │ Linear solve  │  1.3523 │     8.02 % │  78.4360 │
# │ Linear setup  │  5.7961 │    34.38 % │ 336.1764 │
# │ Precond apply │  0.9046 │    26.64 % │ 260.5301 │
# │ Update        │  0.3863 │     2.29 % │  22.4049 │
# │ Convergence   │  0.1906 │     1.34 % │  13.1500 │
# │ Input/Output  │  0.0223 │     0.03 % │   0.2455 │
# │ Other         │  0.1701 │     1.01 % │   9.8675 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 16.8586 │   100.00 % │ 977.7962 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │ 11 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     58.0 │      5.27273 │   58 (0) │
# │ Linearization  │     69.0 │      6.27273 │   69 (0) │
# │ Linear solver  │    148.0 │      13.4545 │  148 (0) │
# │ Precond apply  │    296.0 │      26.9091 │  296 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.8396 │     4.89 % │  48.6980 │
# │ Equations     │  2.2003 │    15.24 % │ 151.8173 │
# │ Assembly      │  0.8526 │     5.90 % │  58.8325 │
# │ Linear solve  │  1.4043 │     8.17 % │  81.4496 │
# │ Linear setup  │  5.8621 │    34.12 % │ 339.9998 │
# │ Precond apply │  0.9115 │    27.08 % │ 269.8003 │
# │ Update        │  0.3853 │     2.24 % │  22.3476 │
# │ Convergence   │  0.1920 │     1.33 % │  13.2499 │
# │ Input/Output  │  0.0217 │     0.02 % │   0.2384 │
# │ Other         │  0.1709 │     0.99 % │   9.9098 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 17.1783 │   100.00 % │ 996.3433 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │ 11 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     54.0 │      4.90909 │   54 (0) │
# │ Linearization  │     65.0 │      5.90909 │   65 (0) │
# │ Linear solver  │    138.0 │      12.5455 │  138 (0) │
# │ Precond apply  │    276.0 │      25.0909 │  276 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.7734 │     4.63 % │  41.7638 │
# │ Equations     │  2.1195 │    15.28 % │ 137.7701 │
# │ Assembly      │  0.8231 │     5.94 % │  53.5024 │
# │ Linear solve  │  1.4491 │     8.68 % │  78.2499 │
# │ Linear setup  │  5.5840 │    33.45 % │ 301.5383 │
# │ Precond apply │  0.8977 │    27.49 % │ 247.7616 │
# │ Update        │  0.3658 │     2.19 % │  19.7540 │
# │ Convergence   │  0.1758 │     1.27 % │  11.4268 │
# │ Input/Output  │  0.0231 │     0.03 % │   0.2539 │
# │ Other         │  0.1739 │     1.04 % │   9.3884 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 16.6928 │   100.00 % │ 901.4093 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │ 11 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     56.0 │      5.09091 │   56 (0) │
# │ Linearization  │     67.0 │      6.09091 │   67 (0) │
# │ Linear solver  │    144.0 │      13.0909 │  144 (0) │
# │ Precond apply  │    288.0 │      26.1818 │  288 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.8344 │     4.87 % │  46.7252 │
# │ Equations     │  2.1886 │    15.30 % │ 146.6359 │
# │ Assembly      │  0.8436 │     5.90 % │  56.5223 │
# │ Linear solve  │  1.3576 │     7.93 % │  76.0252 │
# │ Linear setup  │  5.8624 │    34.25 % │ 328.2949 │
# │ Precond apply │  0.9021 │    27.10 % │ 259.7905 │
# │ Update        │  0.3881 │     2.27 % │  21.7317 │
# │ Convergence   │  0.1919 │     1.34 % │  12.8542 │
# │ Input/Output  │  0.0232 │     0.03 % │   0.2550 │
# │ Other         │  0.1752 │     1.02 % │   9.8130 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 17.1187 │   100.00 % │ 958.6478 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │ 11 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     56.0 │      5.09091 │   56 (0) │
# │ Linearization  │     67.0 │      6.09091 │   67 (0) │
# │ Linear solver  │    138.0 │      12.5455 │  138 (0) │
# │ Precond apply  │    276.0 │      25.0909 │  276 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬────────╮
# │ Timing type   │    Each │   Relative │  Total │
# │               │      ms │ Percentage │      s │
# ├───────────────┼─────────┼────────────┼────────┤
# │ Properties    │  0.8052 │     1.80 % │ 0.0451 │
# │ Equations     │  2.1424 │     5.73 % │ 0.1435 │
# │ Assembly      │  0.8342 │     2.23 % │ 0.0559 │
# │ Linear solve  │  1.3053 │     2.92 % │ 0.0731 │
# │ Linear setup  │ 33.8191 │    75.64 % │ 1.8939 │
# │ Precond apply │  0.9023 │     9.95 % │ 0.2490 │
# │ Update        │  0.3766 │     0.84 % │ 0.0211 │
# │ Convergence   │  0.1846 │     0.49 % │ 0.0124 │
# │ Input/Output  │  0.0247 │     0.01 % │ 0.0003 │
# │ Other         │  0.1730 │     0.39 % │ 0.0097 │
# ├───────────────┼─────────┼────────────┼────────┤
# │ Total         │ 44.7132 │   100.00 % │ 2.5039 │
# ╰───────────────┴─────────┴────────────┴────────╯
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │ 11 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     56.0 │      5.09091 │   56 (0) │
# │ Linearization  │     67.0 │      6.09091 │   67 (0) │
# │ Linear solver  │    152.0 │      13.8182 │  152 (0) │
# │ Precond apply  │    304.0 │      27.6364 │  304 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.8101 │     4.75 % │  45.3653 │
# │ Equations     │  2.1582 │    15.13 % │ 144.5995 │
# │ Assembly      │  0.8402 │     5.89 % │  56.2916 │
# │ Linear solve  │  1.4167 │     8.30 % │  79.3374 │
# │ Linear setup  │  5.6287 │    32.99 % │ 315.2061 │
# │ Precond apply │  0.8930 │    28.41 % │ 271.4635 │
# │ Update        │  0.3751 │     2.20 % │  21.0042 │
# │ Convergence   │  0.1838 │     1.29 % │  12.3134 │
# │ Input/Output  │  0.0216 │     0.02 % │   0.2376 │
# │ Other         │  0.1726 │     1.01 % │   9.6651 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 17.0622 │   100.00 % │ 955.4838 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# Noise norm: 3.3953966e11
# SNR: 8.0
# Noise norm: 3.3955863e11
# SNR: 8.0
# Noise norm: 3.3990145e11
# SNR: 8.0
# Noise norm: 3.3963888e11
# SNR: 8.0
# Noise norm: 3.3973007e11
# SNR: 8.0
# Noise norm: 3.3976254e11
# SNR: 8.0
# Noise norm: 3.3943952e11
# SNR: 8.0
# Noise norm: 3.3961676e11
# SNR: 8.0
# Noise norm: 3.396191e11
# SNR: 8.0
# Noise norm: 3.397713e11
# SNR: 8.0
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │  9 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     46.0 │      5.11111 │   46 (0) │
# │ Linearization  │     55.0 │      6.11111 │   55 (0) │
# │ Linear solver  │    157.0 │      17.4444 │  157 (0) │
# │ Precond apply  │    314.0 │      34.8889 │  314 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.7976 │     4.15 % │  36.6875 │
# │ Equations     │  2.1334 │    13.26 % │ 117.3375 │
# │ Assembly      │  0.8317 │     5.17 % │  45.7438 │
# │ Linear solve  │  1.6957 │     8.82 % │  78.0017 │
# │ Linear setup  │  6.3112 │    32.81 % │ 290.3149 │
# │ Precond apply │  0.8960 │    31.80 % │ 281.3461 │
# │ Update        │  0.3720 │     1.93 % │  17.1137 │
# │ Convergence   │  0.1815 │     1.13 % │   9.9800 │
# │ Input/Output  │  0.0239 │     0.02 % │   0.2149 │
# │ Other         │  0.1732 │     0.90 % │   7.9669 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 19.2328 │   100.00 % │ 884.7068 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │ 10 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     54.0 │          5.4 │   54 (0) │
# │ Linearization  │     64.0 │          6.4 │   64 (0) │
# │ Linear solver  │    161.0 │         16.1 │  161 (0) │
# │ Precond apply  │    322.0 │         32.2 │  322 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.7840 │     4.50 % │  42.3376 │
# │ Equations     │  2.1140 │    14.39 % │ 135.2967 │
# │ Assembly      │  0.8283 │     5.64 % │  53.0095 │
# │ Linear solve  │  1.5222 │     8.74 % │  82.1972 │
# │ Linear setup  │  5.4980 │    31.57 % │ 296.8937 │
# │ Precond apply │  0.9030 │    30.92 % │ 290.7635 │
# │ Update        │  0.3660 │     2.10 % │  19.7654 │
# │ Convergence   │  0.1771 │     1.21 % │  11.3345 │
# │ Input/Output  │  0.0214 │     0.02 % │   0.2139 │
# │ Other         │  0.1612 │     0.93 % │   8.7027 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 17.4169 │   100.00 % │ 940.5147 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │  9 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     45.0 │          5.0 │   45 (0) │
# │ Linearization  │     54.0 │          6.0 │   54 (0) │
# │ Linear solver  │    151.0 │      16.7778 │  151 (0) │
# │ Precond apply  │    302.0 │      33.5556 │  302 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.8227 │     4.44 % │  37.0232 │
# │ Equations     │  2.1636 │    14.00 % │ 116.8358 │
# │ Assembly      │  0.8383 │     5.42 % │  45.2696 │
# │ Linear solve  │  1.6777 │     9.04 % │  75.4976 │
# │ Linear setup  │  5.6406 │    30.41 % │ 253.8287 │
# │ Precond apply │  0.8964 │    32.43 % │ 270.7080 │
# │ Update        │  0.3867 │     2.08 % │  17.4005 │
# │ Convergence   │  0.1867 │     1.21 % │  10.0830 │
# │ Input/Output  │  0.0268 │     0.03 % │   0.2412 │
# │ Other         │  0.1743 │     0.94 % │   7.8448 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 18.5496 │   100.00 % │ 834.7323 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │  9 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     44.0 │      4.88889 │   44 (0) │
# │ Linearization  │     53.0 │      5.88889 │   53 (0) │
# │ Linear solver  │    146.0 │      16.2222 │  146 (0) │
# │ Precond apply  │    292.0 │      32.4444 │  292 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.8431 │     4.49 % │  37.0960 │
# │ Equations     │  2.1757 │    13.95 % │ 115.3138 │
# │ Assembly      │  0.8456 │     5.42 % │  44.8182 │
# │ Linear solve  │  1.7046 │     9.07 % │  75.0019 │
# │ Linear setup  │  5.7857 │    30.80 % │ 254.5688 │
# │ Precond apply │  0.9060 │    32.00 % │ 264.5448 │
# │ Update        │  0.3844 │     2.05 % │  16.9117 │
# │ Convergence   │  0.1916 │     1.23 % │  10.1555 │
# │ Input/Output  │  0.0239 │     0.03 % │   0.2147 │
# │ Other         │  0.1817 │     0.97 % │   7.9952 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 18.7868 │   100.00 % │ 826.6205 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │ 10 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     54.0 │          5.4 │   54 (0) │
# │ Linearization  │     64.0 │          6.4 │   64 (0) │
# │ Linear solver  │    163.0 │         16.3 │  163 (0) │
# │ Precond apply  │    326.0 │         32.6 │  326 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.8400 │     4.64 % │  45.3585 │
# │ Equations     │  2.1896 │    14.34 % │ 140.1344 │
# │ Assembly      │  0.8479 │     5.55 % │  54.2651 │
# │ Linear solve  │  1.5880 │     8.77 % │  85.7536 │
# │ Linear setup  │  5.8241 │    32.17 % │ 314.5025 │
# │ Precond apply │  0.9042 │    30.15 % │ 294.7621 │
# │ Update        │  0.3866 │     2.14 % │  20.8751 │
# │ Convergence   │  0.1973 │     1.29 % │  12.6263 │
# │ Input/Output  │  0.0248 │     0.03 % │   0.2482 │
# │ Other         │  0.1672 │     0.92 % │   9.0304 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 18.1029 │   100.00 % │ 977.5562 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │ 10 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     49.0 │          4.9 │   49 (0) │
# │ Linearization  │     59.0 │          5.9 │   59 (0) │
# │ Linear solver  │    158.0 │         15.8 │  158 (0) │
# │ Precond apply  │    316.0 │         31.6 │  316 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.8261 │     4.42 % │  40.4789 │
# │ Equations     │  2.1883 │    14.10 % │ 129.1105 │
# │ Assembly      │  0.8419 │     5.42 % │  49.6717 │
# │ Linear solve  │  1.6366 │     8.76 % │  80.1949 │
# │ Linear setup  │  6.0192 │    32.20 % │ 294.9426 │
# │ Precond apply │  0.8939 │    30.84 % │ 282.4567 │
# │ Update        │  0.3803 │     2.03 % │  18.6331 │
# │ Convergence   │  0.1903 │     1.23 % │  11.2285 │
# │ Input/Output  │  0.0231 │     0.03 % │   0.2306 │
# │ Other         │  0.1819 │     0.97 % │   8.9147 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 18.6911 │   100.00 % │ 915.8623 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │  9 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     48.0 │      5.33333 │   48 (0) │
# │ Linearization  │     57.0 │      6.33333 │   57 (0) │
# │ Linear solver  │    157.0 │      17.4444 │  157 (0) │
# │ Precond apply  │    314.0 │      34.8889 │  314 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.7835 │     4.33 % │  37.6088 │
# │ Equations     │  2.1085 │    13.82 % │ 120.1822 │
# │ Assembly      │  0.8299 │     5.44 % │  47.3066 │
# │ Linear solve  │  1.6551 │     9.14 % │  79.4428 │
# │ Linear setup  │  5.5777 │    30.79 % │ 267.7282 │
# │ Precond apply │  0.8963 │    32.37 % │ 281.4491 │
# │ Update        │  0.3624 │     2.00 % │  17.3956 │
# │ Convergence   │  0.1765 │     1.16 % │  10.0592 │
# │ Input/Output  │  0.0452 │     0.05 % │   0.4064 │
# │ Other         │  0.1652 │     0.91 % │   7.9295 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 18.1148 │   100.00 % │ 869.5084 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │ 10 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     51.0 │          5.1 │   51 (0) │
# │ Linearization  │     61.0 │          6.1 │   61 (0) │
# │ Linear solver  │    143.0 │         14.3 │  143 (0) │
# │ Precond apply  │    286.0 │         28.6 │  286 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.8416 │     4.78 % │  42.9219 │
# │ Equations     │  2.1965 │    14.92 % │ 133.9840 │
# │ Assembly      │  0.8452 │     5.74 % │  51.5581 │
# │ Linear solve  │  1.4931 │     8.48 % │  76.1463 │
# │ Linear setup  │  5.7657 │    32.75 % │ 294.0511 │
# │ Precond apply │  0.9046 │    28.82 % │ 258.7265 │
# │ Update        │  0.3868 │     2.20 % │  19.7290 │
# │ Convergence   │  0.1903 │     1.29 % │  11.6067 │
# │ Input/Output  │  0.0251 │     0.03 % │   0.2514 │
# │ Other         │  0.1743 │     0.99 % │   8.8873 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 17.6051 │   100.00 % │ 897.8623 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │ 10 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     51.0 │          5.1 │   51 (0) │
# │ Linearization  │     61.0 │          6.1 │   61 (0) │
# │ Linear solver  │    145.0 │         14.5 │  145 (0) │
# │ Precond apply  │    290.0 │         29.0 │  290 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.8479 │     4.80 % │  43.2407 │
# │ Equations     │  2.1963 │    14.87 % │ 133.9765 │
# │ Assembly      │  0.8426 │     5.71 % │  51.3972 │
# │ Linear solve  │  1.4928 │     8.45 % │  76.1353 │
# │ Linear setup  │  5.7396 │    32.50 % │ 292.7199 │
# │ Precond apply │  0.9056 │    29.15 % │ 262.6193 │
# │ Update        │  0.3878 │     2.20 % │  19.7771 │
# │ Convergence   │  0.1922 │     1.30 % │  11.7268 │
# │ Input/Output  │  0.0230 │     0.03 % │   0.2297 │
# │ Other         │  0.1761 │     1.00 % │   8.9819 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 17.6628 │   100.00 % │ 900.8045 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │ 10 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     49.0 │          4.9 │   49 (0) │
# │ Linearization  │     59.0 │          5.9 │   59 (0) │
# │ Linear solver  │    145.0 │         14.5 │  145 (0) │
# │ Precond apply  │    290.0 │         29.0 │  290 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.7846 │     4.48 % │  38.4449 │
# │ Equations     │  2.1033 │    14.45 % │ 124.0918 │
# │ Assembly      │  0.8250 │     5.67 % │  48.6752 │
# │ Linear solve  │  1.5193 │     8.67 % │  74.4462 │
# │ Linear setup  │  5.6361 │    32.17 % │ 276.1687 │
# │ Precond apply │  0.8955 │    30.25 % │ 259.7071 │
# │ Update        │  0.3653 │     2.08 % │  17.9016 │
# │ Convergence   │  0.1776 │     1.22 % │  10.4786 │
# │ Input/Output  │  0.0207 │     0.02 % │   0.2073 │
# │ Other         │  0.1729 │     0.99 % │   8.4744 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 17.5224 │   100.00 % │ 858.5959 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# Noise norm: 3.4078104e11
# SNR: 8.0
# Noise norm: 3.408994e11
# SNR: 8.0
# Noise norm: 3.4004238e11
# SNR: 8.0
# Noise norm: 3.4144577e11
# SNR: 8.0
# Noise norm: 3.383157e11
# SNR: 8.0
# Noise norm: 3.394126e11
# SNR: 8.0
# Noise norm: 3.3851543e11
# SNR: 8.0
# Noise norm: 3.4325293e11
# SNR: 8.0
# Noise norm: 3.4018696e11
# SNR: 8.0
# Noise norm: 3.4236563e11
# SNR: 8.0
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │ 10 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     51.0 │          5.1 │   51 (0) │
# │ Linearization  │     61.0 │          6.1 │   61 (0) │
# │ Linear solver  │    169.0 │         16.9 │  169 (0) │
# │ Precond apply  │    338.0 │         33.8 │  338 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.7930 │     4.40 % │  40.4430 │
# │ Equations     │  2.1188 │    14.06 % │ 129.2470 │
# │ Assembly      │  0.8307 │     5.51 % │  50.6707 │
# │ Linear solve  │  1.6856 │     9.35 % │  85.9663 │
# │ Linear setup  │  5.3333 │    29.58 % │ 271.9991 │
# │ Precond apply │  0.8963 │    32.95 % │ 302.9497 │
# │ Update        │  0.3627 │     2.01 % │  18.4992 │
# │ Convergence   │  0.1768 │     1.17 % │  10.7854 │
# │ Input/Output  │  0.0218 │     0.02 % │   0.2180 │
# │ Other         │  0.1704 │     0.95 % │   8.6928 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 18.0288 │   100.00 % │ 919.4712 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │  9 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     50.0 │      5.55556 │   50 (0) │
# │ Linearization  │     59.0 │      6.55556 │   59 (0) │
# │ Linear solver  │    172.0 │      19.1111 │  172 (0) │
# │ Precond apply  │    344.0 │      38.2222 │  344 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.7889 │     4.34 % │  39.4439 │
# │ Equations     │  2.1105 │    13.69 % │ 124.5186 │
# │ Assembly      │  0.8274 │     5.37 % │  48.8145 │
# │ Linear solve  │  1.7126 │     9.41 % │  85.6289 │
# │ Linear setup  │  5.3314 │    29.30 % │ 266.5711 │
# │ Precond apply │  0.8949 │    33.84 % │ 307.8609 │
# │ Update        │  0.3621 │     1.99 % │  18.1035 │
# │ Convergence   │  0.1795 │     1.16 % │  10.5923 │
# │ Input/Output  │  0.0241 │     0.02 % │   0.2165 │
# │ Other         │  0.1584 │     0.87 % │   7.9197 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 18.1934 │   100.00 % │ 909.6700 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │  8 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     44.0 │          5.5 │   44 (0) │
# │ Linearization  │     52.0 │          6.5 │   52 (0) │
# │ Linear solver  │    140.0 │         17.5 │  140 (0) │
# │ Precond apply  │    280.0 │         35.0 │  280 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.8481 │     4.64 % │  37.3171 │
# │ Equations     │  2.1837 │    14.12 % │ 113.5510 │
# │ Assembly      │  0.8460 │     5.47 % │  43.9894 │
# │ Linear solve  │  1.6191 │     8.86 % │  71.2411 │
# │ Linear setup  │  5.6504 │    30.91 % │ 248.6164 │
# │ Precond apply │  0.9116 │    31.74 % │ 255.2553 │
# │ Update        │  0.3855 │     2.11 % │  16.9639 │
# │ Convergence   │  0.1927 │     1.25 % │  10.0183 │
# │ Input/Output  │  0.0316 │     0.03 % │   0.2530 │
# │ Other         │  0.1615 │     0.88 % │   7.1080 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 18.2799 │   100.00 % │ 804.3134 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │  9 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     51.0 │      5.66667 │   51 (0) │
# │ Linearization  │     60.0 │      6.66667 │   60 (0) │
# │ Linear solver  │    164.0 │      18.2222 │  164 (0) │
# │ Precond apply  │    328.0 │      36.4444 │  328 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.8431 │     4.62 % │  42.9982 │
# │ Equations     │  2.1672 │    13.98 % │ 130.0342 │
# │ Assembly      │  0.8496 │     5.48 % │  50.9754 │
# │ Linear solve  │  1.6310 │     8.94 % │  83.1822 │
# │ Linear setup  │  5.6635 │    31.05 % │ 288.8387 │
# │ Precond apply │  0.8980 │    31.67 % │ 294.5535 │
# │ Update        │  0.3845 │     2.11 % │  19.6073 │
# │ Convergence   │  0.1913 │     1.23 % │  11.4806 │
# │ Input/Output  │  0.0253 │     0.02 % │   0.2278 │
# │ Other         │  0.1622 │     0.89 % │   8.2711 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 18.2386 │   100.00 % │ 930.1690 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │  9 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     49.0 │      5.44444 │   49 (0) │
# │ Linearization  │     58.0 │      6.44444 │   58 (0) │
# │ Linear solver  │    181.0 │      20.1111 │  181 (0) │
# │ Precond apply  │    362.0 │      40.2222 │  362 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.8295 │     4.34 % │  40.6446 │
# │ Equations     │  2.2426 │    13.89 % │ 130.0721 │
# │ Assembly      │  0.8393 │     5.20 % │  48.6769 │
# │ Linear solve  │  1.8440 │     9.65 % │  90.3537 │
# │ Linear setup  │  5.4129 │    28.32 % │ 265.2341 │
# │ Precond apply │  0.8944 │    34.57 % │ 323.7829 │
# │ Update        │  0.3748 │     1.96 % │  18.3637 │
# │ Convergence   │  0.1892 │     1.17 % │  10.9711 │
# │ Input/Output  │  0.0402 │     0.04 % │   0.3617 │
# │ Other         │  0.1650 │     0.86 % │   8.0850 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 19.1132 │   100.00 % │ 936.5458 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │  9 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     53.0 │      5.88889 │   53 (0) │
# │ Linearization  │     62.0 │      6.88889 │   62 (0) │
# │ Linear solver  │    170.0 │      18.8889 │  170 (0) │
# │ Precond apply  │    340.0 │      37.7778 │  340 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.8489 │     4.64 % │  44.9911 │
# │ Equations     │  2.1824 │    13.97 % │ 135.3074 │
# │ Assembly      │  0.8510 │     5.45 % │  52.7615 │
# │ Linear solve  │  1.6650 │     9.11 % │  88.2433 │
# │ Linear setup  │  5.6248 │    30.77 % │ 298.1143 │
# │ Precond apply │  0.9067 │    31.82 % │ 308.2855 │
# │ Update        │  0.3841 │     2.10 % │  20.3566 │
# │ Convergence   │  0.1970 │     1.26 % │  12.2142 │
# │ Input/Output  │  0.0265 │     0.02 % │   0.2386 │
# │ Other         │  0.1562 │     0.85 % │   8.2766 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 18.2790 │   100.00 % │ 968.7891 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │ 11 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     67.0 │      6.09091 │  67 (15) │
# │ Linearization  │     78.0 │      7.09091 │  78 (16) │
# │ Linear solver  │    220.0 │         20.0 │ 220 (49) │
# │ Precond apply  │    440.0 │         40.0 │ 440 (98) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬────────╮
# │ Timing type   │    Each │   Relative │  Total │
# │               │      ms │ Percentage │      s │
# ├───────────────┼─────────┼────────────┼────────┤
# │ Properties    │  0.8143 │     3.38 % │ 0.0546 │
# │ Equations     │  2.1280 │    10.29 % │ 0.1660 │
# │ Assembly      │  0.8344 │     4.04 % │ 0.0651 │
# │ Linear solve  │  1.6476 │     6.84 % │ 0.1104 │
# │ Linear setup  │  6.0684 │    25.21 % │ 0.4066 │
# │ Precond apply │  0.8938 │    24.38 % │ 0.3933 │
# │ Update        │  0.3704 │     1.54 % │ 0.0248 │
# │ Convergence   │  0.1828 │     0.88 % │ 0.0143 │
# │ Input/Output  │  0.0250 │     0.02 % │ 0.0003 │
# │ Other         │  5.6358 │    23.41 % │ 0.3776 │
# ├───────────────┼─────────┼────────────┼────────┤
# │ Total         │ 24.0719 │   100.00 % │ 1.6128 │
# ╰───────────────┴─────────┴────────────┴────────╯
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │  9 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     52.0 │      5.77778 │   52 (0) │
# │ Linearization  │     61.0 │      6.77778 │   61 (0) │
# │ Linear solver  │    157.0 │      17.4444 │  157 (0) │
# │ Precond apply  │    314.0 │      34.8889 │  314 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.8527 │     4.77 % │  44.3421 │
# │ Equations     │  2.1776 │    14.28 % │ 132.8324 │
# │ Assembly      │  0.8495 │     5.57 % │  51.8169 │
# │ Linear solve  │  1.6015 │     8.95 % │  83.2756 │
# │ Linear setup  │  5.6196 │    31.41 % │ 292.2176 │
# │ Precond apply │  0.9087 │    30.67 % │ 285.3186 │
# │ Update        │  0.3859 │     2.16 % │  20.0669 │
# │ Convergence   │  0.1910 │     1.25 % │  11.6486 │
# │ Input/Output  │  0.0449 │     0.04 % │   0.4037 │
# │ Other         │  0.1592 │     0.89 % │   8.2782 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 17.8885 │   100.00 % │ 930.2005 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │ 10 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     48.0 │          4.8 │   48 (0) │
# │ Linearization  │     58.0 │          5.8 │   58 (0) │
# │ Linear solver  │    155.0 │         15.5 │  155 (0) │
# │ Precond apply  │    310.0 │         31.0 │  310 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.7921 │     4.40 % │  38.0207 │
# │ Equations     │  2.1186 │    14.23 % │ 122.8788 │
# │ Assembly      │  0.8279 │     5.56 % │  48.0163 │
# │ Linear solve  │  1.6221 │     9.02 % │  77.8628 │
# │ Linear setup  │  5.4571 │    30.34 % │ 261.9408 │
# │ Precond apply │  0.8961 │    32.18 % │ 277.8016 │
# │ Update        │  0.3684 │     2.05 % │  17.6818 │
# │ Convergence   │  0.1801 │     1.21 % │  10.4486 │
# │ Input/Output  │  0.0199 │     0.02 % │   0.1993 │
# │ Other         │  0.1757 │     0.98 % │   8.4331 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 17.9851 │   100.00 % │ 863.2838 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │  9 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     47.0 │      5.22222 │   47 (0) │
# │ Linearization  │     56.0 │      6.22222 │   56 (0) │
# │ Linear solver  │    150.0 │      16.6667 │  150 (0) │
# │ Precond apply  │    300.0 │      33.3333 │  300 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.8543 │     4.58 % │  40.1534 │
# │ Equations     │  2.1959 │    14.04 % │ 122.9727 │
# │ Assembly      │  0.8523 │     5.45 % │  47.7293 │
# │ Linear solve  │  1.6767 │     9.00 % │  78.8049 │
# │ Linear setup  │  5.8773 │    31.54 % │ 276.2328 │
# │ Precond apply │  0.9065 │    31.05 % │ 271.9589 │
# │ Update        │  0.3945 │     2.12 % │  18.5417 │
# │ Convergence   │  0.1978 │     1.26 % │  11.0789 │
# │ Input/Output  │  0.0253 │     0.03 % │   0.2281 │
# │ Other         │  0.1728 │     0.93 % │   8.1199 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 18.6345 │   100.00 % │ 875.8206 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# Noise norm: 3.4269862e11
# SNR: 8.0
# Noise norm: 3.3993343e11
# SNR: 8.0
# Noise norm: 3.3589543e11
# SNR: 8.0
# Noise norm: 3.3670637e11
# SNR: 8.0
# Noise norm: 3.3684645e11
# SNR: 8.0
# Noise norm: 3.380205e11
# SNR: 8.0
# Noise norm: 3.3373608e11
# SNR: 8.0
# Noise norm: 3.470042e11
# SNR: 8.0
# Noise norm: 3.3462688e11
# SNR: 8.0
# Noise norm: 3.4635592e11
# SNR: 8.0
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │ 10 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     49.0 │          4.9 │   49 (0) │
# │ Linearization  │     59.0 │          5.9 │   59 (0) │
# │ Linear solver  │    182.0 │         18.2 │  182 (0) │
# │ Precond apply  │    364.0 │         36.4 │  364 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.8246 │     4.25 % │  40.4041 │
# │ Equations     │  2.1544 │    13.37 % │ 127.1123 │
# │ Assembly      │  0.8437 │     5.24 % │  49.7772 │
# │ Linear solve  │  1.9143 │     9.87 % │  93.8005 │
# │ Linear setup  │  5.4652 │    28.18 % │ 267.7952 │
# │ Precond apply │  0.9158 │    35.07 % │ 333.3554 │
# │ Update        │  0.3699 │     1.91 % │  18.1228 │
# │ Convergence   │  0.1867 │     1.16 % │  11.0137 │
# │ Input/Output  │  0.0231 │     0.02 % │   0.2313 │
# │ Other         │  0.1797 │     0.93 % │   8.8035 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 19.3962 │   100.00 % │ 950.4161 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │ 10 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     53.0 │          5.3 │   53 (0) │
# │ Linearization  │     63.0 │          6.3 │   63 (0) │
# │ Linear solver  │    174.0 │         17.4 │  174 (0) │
# │ Precond apply  │    348.0 │         34.8 │  348 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.8528 │     4.61 % │  45.1959 │
# │ Equations     │  2.1937 │    14.11 % │ 138.2037 │
# │ Assembly      │  0.8504 │     5.47 % │  53.5774 │
# │ Linear solve  │  1.6965 │     9.18 % │  89.9134 │
# │ Linear setup  │  5.5900 │    30.25 % │ 296.2691 │
# │ Precond apply │  0.9039 │    32.12 % │ 314.5550 │
# │ Update        │  0.3866 │     2.09 % │  20.4888 │
# │ Convergence   │  0.1901 │     1.22 % │  11.9766 │
# │ Input/Output  │  0.0231 │     0.02 % │   0.2305 │
# │ Other         │  0.1697 │     0.92 % │   8.9924 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 18.4793 │   100.00 % │ 979.4028 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │ 11 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     59.0 │      5.36364 │   59 (0) │
# │ Linearization  │     70.0 │      6.36364 │   70 (0) │
# │ Linear solver  │    198.0 │         18.0 │  198 (0) │
# │ Precond apply  │    396.0 │         36.0 │  396 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬────────╮
# │ Timing type   │    Each │   Relative │  Total │
# │               │      ms │ Percentage │      s │
# ├───────────────┼─────────┼────────────┼────────┤
# │ Properties    │  0.8492 │     4.57 % │ 0.0501 │
# │ Equations     │  2.1964 │    14.03 % │ 0.1537 │
# │ Assembly      │  0.8492 │     5.42 % │ 0.0594 │
# │ Linear solve  │  1.7235 │     9.28 % │ 0.1017 │
# │ Linear setup  │  5.5542 │    29.91 % │ 0.3277 │
# │ Precond apply │  0.9009 │    32.56 % │ 0.3568 │
# │ Update        │  0.3834 │     2.06 % │ 0.0226 │
# │ Convergence   │  0.1920 │     1.23 % │ 0.0134 │
# │ Input/Output  │  0.0219 │     0.02 % │ 0.0002 │
# │ Other         │  0.1695 │     0.91 % │ 0.0100 │
# ├───────────────┼─────────┼────────────┼────────┤
# │ Total         │ 18.5717 │   100.00 % │ 1.0957 │
# ╰───────────────┴─────────┴────────────┴────────╯
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │ 10 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     48.0 │          4.8 │   48 (0) │
# │ Linearization  │     58.0 │          5.8 │   58 (0) │
# │ Linear solver  │    186.0 │         18.6 │  186 (0) │
# │ Precond apply  │    372.0 │         37.2 │  372 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.8059 │     4.18 % │  38.6824 │
# │ Equations     │  2.2202 │    13.91 % │ 128.7712 │
# │ Assembly      │  0.8279 │     5.19 % │  48.0182 │
# │ Linear solve  │  1.8924 │     9.81 % │  90.8376 │
# │ Linear setup  │  5.1961 │    26.95 % │ 249.4138 │
# │ Precond apply │  0.8950 │    35.97 % │ 332.9456 │
# │ Update        │  0.3695 │     1.92 % │  17.7384 │
# │ Convergence   │  0.1781 │     1.12 % │  10.3302 │
# │ Input/Output  │  0.0199 │     0.02 % │   0.1992 │
# │ Other         │  0.1806 │     0.94 % │   8.6692 │
# ├───────────────┼─────────┼────────────┼──────────┤
# ...
# │ Precond apply │  0.9100 │    34.13 % │ 325.7664 │
# │ Update        │  0.3891 │     2.00 % │  19.0645 │
# │ Convergence   │  0.1951 │     1.19 % │  11.3177 │
# │ Input/Output  │  0.0244 │     0.02 % │   0.2198 │
# │ Other         │  0.1696 │     0.87 % │   8.3124 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 19.4813 │   100.00 % │ 954.5839 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# Noise norm: 3.4366285e11
# SNR: 8.0
# Noise norm: 3.3997174e11
# SNR: 8.0
# Noise norm: 3.3517132e11
# SNR: 8.0
# Noise norm: 3.370026e11
# SNR: 8.0
# Noise norm: 3.373942e11
# SNR: 8.0
# Noise norm: 3.3650534e11
# SNR: 8.0
# Noise norm: 3.3374896e11
# SNR: 8.0
# Noise norm: 3.497531e11
# SNR: 8.0
# Noise norm: 3.316578e11
# SNR: 8.0
# Noise norm: 3.4562707e11
# SNR: 8.0
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │  9 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     33.0 │      3.66667 │   33 (0) │
# │ Linearization  │     42.0 │      4.66667 │   42 (0) │
# │ Linear solver  │    147.0 │      16.3333 │  147 (0) │
# │ Precond apply  │    294.0 │      32.6667 │  294 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.7952 │     3.85 % │  26.2429 │
# │ Equations     │  2.0928 │    12.91 % │  87.8962 │
# │ Assembly      │  0.8221 │     5.07 % │  34.5295 │
# │ Linear solve  │  2.0947 │    10.15 % │  69.1265 │
# │ Linear setup  │  5.3697 │    26.02 % │ 177.1988 │
# │ Precond apply │  0.8818 │    38.06 % │ 259.2384 │
# │ Update        │  0.3613 │     1.75 % │  11.9222 │
# │ Convergence   │  0.1766 │     1.09 % │   7.4177 │
# │ Input/Output  │  0.0202 │     0.03 % │   0.1814 │
# │ Other         │  0.2217 │     1.07 % │   7.3171 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 20.6385 │   100.00 % │ 681.0707 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │ 10 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     42.0 │          4.2 │   42 (0) │
# │ Linearization  │     52.0 │          5.2 │   52 (0) │
# │ Linear solver  │    154.0 │         15.4 │  154 (0) │
# │ Precond apply  │    308.0 │         30.8 │  308 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.7944 │     4.23 % │  33.3663 │
# │ Equations     │  2.0879 │    13.75 % │ 108.5709 │
# │ Assembly      │  0.8213 │     5.41 % │  42.7073 │
# │ Linear solve  │  1.7842 │     9.49 % │  74.9368 │
# │ Linear setup  │  5.3591 │    28.51 % │ 225.0822 │
# │ Precond apply │  0.8840 │    34.49 % │ 272.2796 │
# │ Update        │  0.3568 │     1.90 % │  14.9873 │
# │ Convergence   │  0.1755 │     1.16 % │   9.1246 │
# │ Input/Output  │  0.0190 │     0.02 % │   0.1905 │
# │ Other         │  0.1969 │     1.05 % │   8.2706 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 18.7980 │   100.00 % │ 789.5161 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │  9 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     37.0 │      4.11111 │   37 (0) │
# │ Linearization  │     46.0 │      5.11111 │   46 (0) │
# │ Linear solver  │    143.0 │      15.8889 │  143 (0) │
# │ Precond apply  │    286.0 │      31.7778 │  286 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.8055 │     4.17 % │  29.8052 │
# │ Equations     │  2.1005 │    13.51 % │  96.6214 │
# │ Assembly      │  0.8237 │     5.30 % │  37.8879 │
# │ Linear solve  │  1.8786 │     9.72 % │  69.5100 │
# │ Linear setup  │  5.3723 │    27.79 % │ 198.7749 │
# │ Precond apply │  0.8860 │    35.43 % │ 253.4052 │
# │ Update        │  0.3601 │     1.86 % │  13.3232 │
# │ Convergence   │  0.1797 │     1.16 % │   8.2658 │
# │ Input/Output  │  0.0214 │     0.03 % │   0.1927 │
# │ Other         │  0.2001 │     1.04 % │   7.4041 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 19.3295 │   100.00 % │ 715.1904 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │ 10 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     37.0 │          3.7 │   37 (0) │
# │ Linearization  │     47.0 │          4.7 │   47 (0) │
# │ Linear solver  │    150.0 │         15.0 │  150 (0) │
# │ Precond apply  │    300.0 │         30.0 │  300 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.8476 │     4.14 % │  31.3624 │
# │ Equations     │  2.4180 │    15.01 % │ 113.6454 │
# │ Assembly      │  0.8437 │     5.24 % │  39.6559 │
# │ Linear solve  │  1.9895 │     9.72 % │  73.6119 │
# │ Linear setup  │  5.3484 │    26.13 % │ 197.8890 │
# │ Precond apply │  0.8974 │    35.55 % │ 269.2173 │
# │ Update        │  0.3806 │     1.86 % │  14.0836 │
# │ Convergence   │  0.1939 │     1.20 % │   9.1129 │
# │ Input/Output  │  0.0240 │     0.03 % │   0.2396 │
# │ Other         │  0.2315 │     1.13 % │   8.5639 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 20.4698 │   100.00 % │ 757.3820 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │ 10 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     42.0 │          4.2 │   42 (0) │
# │ Linearization  │     52.0 │          5.2 │   52 (0) │
# │ Linear solver  │    169.0 │         16.9 │  169 (0) │
# │ Precond apply  │    338.0 │         33.8 │  338 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.8552 │     4.25 % │  35.9187 │
# │ Equations     │  2.1792 │    13.41 % │ 113.3171 │
# │ Assembly      │  0.8414 │     5.18 % │  43.7537 │
# │ Linear solve  │  1.9760 │     9.82 % │  82.9916 │
# │ Linear setup  │  5.5037 │    27.35 % │ 231.1575 │
# │ Precond apply │  0.8977 │    35.90 % │ 303.4360 │
# │ Update        │  0.3834 │     1.91 % │  16.1046 │
# │ Convergence   │  0.1871 │     1.15 % │   9.7309 │
# │ Input/Output  │  0.0244 │     0.03 % │   0.2441 │
# │ Other         │  0.2041 │     1.01 % │   8.5730 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 20.1245 │   100.00 % │ 845.2273 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │ 10 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     35.0 │          3.5 │   35 (0) │
# │ Linearization  │     45.0 │          4.5 │   45 (0) │
# │ Linear solver  │    134.0 │         13.4 │  134 (0) │
# │ Precond apply  │    268.0 │         26.8 │  268 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.8241 │     4.15 % │  28.8427 │
# │ Equations     │  2.1364 │    13.83 % │  96.1360 │
# │ Assembly      │  0.8367 │     5.42 % │  37.6520 │
# │ Linear solve  │  1.8631 │     9.38 % │  65.2087 │
# │ Linear setup  │  5.6283 │    28.34 % │ 196.9912 │
# │ Precond apply │  0.8969 │    34.58 % │ 240.3558 │
# │ Update        │  0.3775 │     1.90 % │  13.2133 │
# │ Convergence   │  0.1833 │     1.19 % │   8.2506 │
# │ Input/Output  │  0.0185 │     0.03 % │   0.1852 │
# │ Other         │  0.2326 │     1.17 % │   8.1426 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 19.8565 │   100.00 % │ 694.9781 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │  9 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     37.0 │      4.11111 │   37 (0) │
# │ Linearization  │     46.0 │      5.11111 │   46 (0) │
# │ Linear solver  │    142.0 │      15.7778 │  142 (0) │
# │ Precond apply  │    284.0 │      31.5556 │  284 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.8596 │     4.26 % │  31.8070 │
# │ Equations     │  2.2018 │    13.56 % │ 101.2811 │
# │ Assembly      │  0.8507 │     5.24 % │  39.1314 │
# │ Linear solve  │  1.8779 │     9.30 % │  69.4820 │
# │ Linear setup  │  5.9041 │    29.25 % │ 218.4518 │
# │ Precond apply │  0.8994 │    34.20 % │ 255.4297 │
# │ Update        │  0.3849 │     1.91 % │  14.2419 │
# │ Convergence   │  0.1967 │     1.21 % │   9.0478 │
# │ Input/Output  │  0.0255 │     0.03 % │   0.2296 │
# │ Other         │  0.2097 │     1.04 % │   7.7598 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 20.1855 │   100.00 % │ 746.8619 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │ 10 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     44.0 │          4.4 │   44 (0) │
# │ Linearization  │     54.0 │          5.4 │   54 (0) │
# │ Linear solver  │    145.0 │         14.5 │  145 (0) │
# │ Precond apply  │    290.0 │         29.0 │  290 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.8294 │     4.51 % │  36.4931 │
# │ Equations     │  2.1390 │    14.27 % │ 115.5036 │
# │ Assembly      │  0.8308 │     5.54 % │  44.8638 │
# │ Linear solve  │  1.6287 │     8.85 % │  71.6623 │
# │ Linear setup  │  5.6393 │    30.65 % │ 248.1277 │
# │ Precond apply │  0.8889 │    31.84 % │ 257.7843 │
# │ Update        │  0.3739 │     2.03 % │  16.4507 │
# │ Convergence   │  0.1813 │     1.21 % │   9.7927 │
# │ Input/Output  │  0.0223 │     0.03 % │   0.2225 │
# │ Other         │  0.1954 │     1.06 % │   8.5988 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 18.3977 │   100.00 % │ 809.4995 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │  9 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     33.0 │      3.66667 │   33 (0) │
# │ Linearization  │     42.0 │      4.66667 │   42 (0) │
# │ Linear solver  │    142.0 │      15.7778 │  142 (0) │
# │ Precond apply  │    284.0 │      31.5556 │  284 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.8475 │     4.02 % │  27.9670 │
# │ Equations     │  2.1539 │    12.99 % │  90.4642 │
# │ Assembly      │  0.8366 │     5.05 % │  35.1362 │
# │ Linear solve  │  2.0392 │     9.66 % │  67.2925 │
# │ Linear setup  │  5.9193 │    28.05 % │ 195.3368 │
# │ Precond apply │  0.8874 │    36.19 % │ 252.0136 │
# │ Update        │  0.3859 │     1.83 % │  12.7354 │
# │ Convergence   │  0.1847 │     1.11 % │   7.7582 │
# │ Input/Output  │  0.0218 │     0.03 % │   0.1961 │
# │ Other         │  0.2278 │     1.08 % │   7.5181 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 21.1036 │   100.00 % │ 696.4181 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# ╭────────────────┬──────────┬──────────────┬──────────╮
# │ Iteration type │ Avg/step │ Avg/ministep │    Total │
# │                │  1 steps │ 10 ministeps │ (wasted) │
# ├────────────────┼──────────┼──────────────┼──────────┤
# │ Newton         │     39.0 │          3.9 │   39 (0) │
# │ Linearization  │     49.0 │          4.9 │   49 (0) │
# │ Linear solver  │    152.0 │         15.2 │  152 (0) │
# │ Precond apply  │    304.0 │         30.4 │  304 (0) │
# ╰────────────────┴──────────┴──────────────┴──────────╯
# ╭───────────────┬─────────┬────────────┬──────────╮
# │ Timing type   │    Each │   Relative │    Total │
# │               │      ms │ Percentage │       ms │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Properties    │  0.8585 │     4.25 % │  33.4816 │
# │ Equations     │  2.1765 │    13.55 % │ 106.6495 │
# │ Assembly      │  0.8423 │     5.24 % │  41.2728 │
# │ Linear solve  │  1.8951 │     9.39 % │  73.9070 │
# │ Linear setup  │  5.8449 │    28.96 % │ 227.9508 │
# │ Precond apply │  0.8904 │    34.38 % │ 270.6779 │
# │ Update        │  0.3878 │     1.92 % │  15.1228 │
# │ Convergence   │  0.1916 │     1.19 % │   9.3873 │
# │ Input/Output  │  0.0210 │     0.03 % │   0.2097 │
# │ Other         │  0.2190 │     1.08 % │   8.5408 │
# ├───────────────┼─────────┼────────────┼──────────┤
# │ Total         │ 20.1846 │   100.00 % │ 787.2003 │
# ╰───────────────┴─────────┴────────────┴──────────╯
# Noise norm: 3.4377997e11
# SNR: 8.0
# Noise norm: 3.4031587e11
# SNR: 8.0
# Noise norm: 3.3565354e11
# SNR: 8.0
# Noise norm: 3.371171e11
# SNR: 8.0
# Noise norm: 3.3840425e11
# SNR: 8.0
# Noise norm: 3.3732893e11
# SNR: 8.0
# Noise norm: 3.3441576e11
# SNR: 8.0
# Noise norm: 3.5066115e11
# SNR: 8.0
# Noise norm: 3.3243532e11
# SNR: 8.0
# Noise norm: 3.4494746e11
# SNR: 8.0
# 933.659018 seconds (155.09 M allocations: 36.877 GiB, 49.42% gc time, 0.39% compilation time)
#   ^ timing for running filter loop (EnKF)
# Dict{String, Any} with 11 entries:
#   "observations_clean"      => Any[Ensemble(Dict{Symbol, Array}[Dict(:dshot=>Ma…
#   "observation_times"       => Any[3.1557e7, 6.31139e7, 9.46709e7, 1.26228e8, 1…
#   "observation_clean_means" => Any[Dict{Symbol, Array}(:dshot=>Matrix{Float32}[…
#   "observation_means"       => Any[Dict{Symbol, Array}(:rtm_noisy=>Float32[0.0 …
#   "states"                  => Any[(ensemble = Ensemble(Dict{Symbol, Any}[Dict(…
#   "logs"                    => Any[Dict{Symbol, Any}(:assimilate_data_linear_so…
#   "t"                       => 1.57785e8
#   "state_means"             => Any[Dict{Symbol, Any}(:Permeability=>[1.30921e-1…
#   "observations"            => Any[Ensemble(Dict{Symbol, Array}[Dict(:dshot=>Ma…
#   "state_times"             => Any[3.1557e7, 3.1557e7, 6.31139e7, 6.31139e7, 9.…
#   "ensemble"                => Ensemble(Dict{Symbol, Any}[Dict(:Permeability=>[…

# %%
using JLD2
data2 = Dict(Symbol(k) => v for (k,v) in data)
jldsave(joinpath(savedir, "tutorial-estimator.jld2"); data2...)

# %% [markdown]
# ## Brief math review
#
# There is an unknown state $x$. We know it changes over time according to a transition operator $\mathcal{M}$.
#
# We can observe $x$ indirectly with an observation observation $y$ from observation model $\mathcal{H}$.
#
# We have a transition operator $\mathcal{M}$ and an observation operator $\mathcal{H}$.
#
#
# ## Operators for geologic CO~2~ storage
#
# ### CO~2~ plume physics with Jutul
#
# ### Seismic wave physics with JUDI
#
# ## Set up synthetic system
#
# ### CO~2~ state evolution
#
# ```
# ## states = M()
# ## Plot states
# ```
#
# ### Seismic observations
#
# Observe a few states.
# ```
# ## TODO
# ```
#
# ## Filtering
#
# ### Set up ensemble
#
# ### Predict without observations
#
# ### Assimilation observations
#
# ### Repeat
#
# ## Analyze results
#
# ### Error
#
# ### Uncertainty
